# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Retail_Transaction_Dataset.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   CustomerID          100000 non-null  int64
#  1   ProductID           100000 non-null  object
#  2   Quantity            100000 non-null  int64
#  3   Price               100000 non-null  float64
#  4   TransactionDate     100000 non-null  object
#  5   PaymentMethod       100000 non-null  object
#  6   StoreLocation       100000 non-null  object
#  7   ProductCategory     100000 non-null  object
#  8   DiscountApplied(%)  100000 non-null  float64
#  9   TotalAmount         100000 non-null  float64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 7.6+ MB

# %%
df.head()
# Out:
#    CustomerID ProductID  Quantity      Price   TransactionDate PaymentMethod  \
# 0      109318         C         7  80.079844  12/26/2023 12:32          Cash
# 1      993229         C         4  75.195229     8/5/2023 0:00          Cash
# 2      579675         A         8  31.528816   3/11/2024 18:51          Cash
# 3      799826         D         5  98.880218  10/27/2023 22:00        PayPal
# 4      121413         A         7  93.188512  12/22/2023 11:38          Cash
#
#                                        StoreLocation ProductCategory  \
# 0            176 Andrew Cliffs\nBaileyfort, HI 93354           Books
# 1  11635 William Well Suite 809\nEast Kara, MT 19483      Home Decor
# 2  910 Mendez Ville Suite 909\nPort Lauraland, MO...           Books
# 3  87522 Sharon Corners Suite 500\nLake Tammy, MO...           Books
# 4   0070 Michelle Island Suite 143\nHoland, VA 80142     Electronics
#
#    DiscountApplied(%)  TotalAmount
# 0           18.677100   455.862764
# ...

# %%
# TransactionDate must be cleaned.
df['TransactionDateUpdated']=pd.to_datetime(df['TransactionDate'], format='%m/%d/%Y %H:%M')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   CustomerID              100000 non-null  int64
#  1   ProductID               100000 non-null  object
#  2   Quantity                100000 non-null  int64
#  3   Price                   100000 non-null  float64
#  4   TransactionDate         100000 non-null  object
#  5   PaymentMethod           100000 non-null  object
#  6   StoreLocation           100000 non-null  object
#  7   ProductCategory         100000 non-null  object
#  8   DiscountApplied(%)      100000 non-null  float64
#  9   TotalAmount             100000 non-null  float64
#  10  TransactionDateUpdated  100000 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(3), int64(2), object(5)
# memory usage: 8.4+ MB

# %%
df.describe()
# Out:
#           CustomerID       Quantity          Price  DiscountApplied(%)  \
# count  100000.000000  100000.000000  100000.000000       100000.000000
# mean   500463.982180       5.009290      55.067344           10.020155
# min        14.000000       1.000000      10.000430            0.000046
# 25%    250693.750000       3.000000      32.549474            5.001013
# 50%    499679.000000       5.000000      55.116789           10.030353
# 75%    751104.750000       7.000000      77.456763           15.018367
# max    999997.000000       9.000000      99.999284           19.999585
# std    288460.917524       2.579808      25.971567            5.779534
#
#          TotalAmount         TransactionDateUpdated
# count  100000.000000                         100000
# mean      248.334955  2023-10-29 15:40:05.471399936
# min         8.274825            2023-04-29 22:27:00
# 25%        95.163418            2023-07-30 06:45:15
# 50%       200.368393            2023-10-30 05:12:30
# ...

# %%
df.PaymentMethod.unique()
# Out:
# array(['Cash', 'PayPal', 'Debit Card', 'Credit Card'], dtype=object)

# %%
df['PaymentMethod']=df['PaymentMethod'].str.replace('PayPal', 'UPI')
print(df.PaymentMethod.unique())
# Out:
# ['Cash' 'UPI' 'Debit Card' 'Credit Card']

# %%
df.ProductCategory.unique()
# Out:
# array(['Books', 'Home Decor', 'Electronics', 'Clothing'], dtype=object)

# %%
df.columns
# Out:
# Index(['CustomerID', 'ProductID', 'Quantity', 'Price', 'TransactionDate',
#        'PaymentMethod', 'StoreLocation', 'ProductCategory',
#        'DiscountApplied(%)', 'TotalAmount', 'TransactionDateUpdated'],
#       dtype='object')

# %%
df.StoreLocation.unique()
# Out:
# array(['176 Andrew Cliffs\nBaileyfort, HI 93354',
#        '11635 William Well Suite 809\nEast Kara, MT 19483',
#        '910 Mendez Ville Suite 909\nPort Lauraland, MO 99563', ...,
#        '50653 Kara Lakes\nStephanieborough, RI 94492',
#        '18756 Mcfarland Way Suite 866\nBarnettside, PR 50529',
#        '8046 Hull Drive\nPaulstad, GU 87218'], dtype=object)

# %%
df.drop(columns=['TransactionDate'])
# Out:
#        CustomerID ProductID  Quantity      Price PaymentMethod  \
# 0          109318         C         7  80.079844          Cash
# 1          993229         C         4  75.195229          Cash
# 2          579675         A         8  31.528816          Cash
# 3          799826         D         5  98.880218           UPI
# 4          121413         A         7  93.188512          Cash
# ...           ...       ...       ...        ...           ...
# 99995      726461         A         2  56.078258   Credit Card
# 99996      328056         A         6  88.516406   Credit Card
# 99997      887304         B         4  72.385564   Credit Card
# 99998      326401         C         5  66.542239           UPI
# 99999      771566         C         5  38.087766    Debit Card
#
#                                            StoreLocation ProductCategory  \
# 0                176 Andrew Cliffs\nBaileyfort, HI 93354           Books
# ...

# %%
df.ProductID.unique()
# Out:
# array(['C', 'A', 'D', 'B'], dtype=object)

# %%
df.to_csv('Cleaned_Retail_Transaction_Dataset.csv', index=False)
